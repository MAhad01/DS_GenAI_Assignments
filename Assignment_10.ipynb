# %%
# 1 What is TensorFlow 2.0, and how is it different from TensorFlow 1.x2?

# TensorFlow 2.0 is a major upgrade from TensorFlow 1.x, designed to be more user-friendly and intuitive. Key differences include:

# Eager Execution: Enabled by default, which makes debugging and iteration much easier.

# Simplified API: Many redundant APIs have been removed or replaced with more straightforward options.

# Keras Integration: Keras is now the high-level API for building and training models, simplifying the process.

# Cleaner Syntax: The new tf.function decorator allows for easier transition from eager to graph execution.

# Performance Improvements: Optimized operations for better performance.

# %%
# 2. How do you install TensorFlow 2.0?
# !pip install tensorflow

# %%
# 3. What is the primary function of tf.function in TensorFlow 2.0?

# The tf.function decorator converts a Python function into a TensorFlow computation graph.
# This enables performance optimizations and allows for execution in TensorFlow's graph mode, which can be faster and more efficient.

# %%
# 4. What is the purpose of the Model class in TensorFlow 2.0?

# The Model class in TensorFlow 2.0 (part of Keras) is used to define and train models.
# It provides methods for compiling the model, adding layers, fitting the model to data, evaluating performance, and making predictions.

# %%
# 5. How do you create a neural network using TensorFlow 2.0?

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Create a model
model = Sequential([
    Dense(32, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# 6. What is the importance of Tensor Space in TensorFlow?

# In TensorFlow, tensors are multi-dimensional arrays that represent data.
# They are the primary data structure used in TensorFlow to store and manipulate data.
# Tensors can have different ranks (dimensions) and are used for input data, weights, activations, and more.

# %%
# 7. How can TensorBoard be integrated with TensorFlow 2.0?

import tensorflow as tf
import datetime

# Define model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Prepare data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train = x_train.reshape(-1, 784).astype("float32") / 255
x_test = x_test.reshape(-1, 784).astype("float32") / 255

# Log directory
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# TensorBoard callback
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Train
model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test), callbacks=[tensorboard_callback])
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.8615 - loss: 0.4823 - val_accuracy: 0.9578 - val_loss: 0.1325
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9557 - loss: 0.1511 - val_accuracy: 0.9708 - val_loss: 0.0984
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9690 - loss: 0.1054 - val_accuracy: 0.9752 - val_loss: 0.0794
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9736 - loss: 0.0863 - val_accuracy: 0.9732 - val_loss: 0.0822
# Epoch 5/5
# ...

# %%
# 8. What is the purpose of TensorFlow Playground?
# TensorFlow Playground is an interactive web-based tool that helps users understand neural networks by allowing them to
# visualize and experiment with different network architectures and hyperparameters in real-time.

# %%
# 9. What is Netron, and how is it useful for deep learning models?
# Netron is a viewer for neural network, deep learning, and machine learning models.
# It allows you to visualize the structure of models from various frameworks, including TensorFlow, Keras, and PyTorch, making it easier to understand and debug them.

# %%
# 10. What is the difference between TensorFlow and PyTorch?

# TensorFlow: Known for its high-level APIs, extensive ecosystem, and production readiness. It uses static computation graphs.

# PyTorch: Favored for its dynamic computation graphs (eager execution), ease of use, and extensive debugging capabilities. It is also popular in research settings.

# %%
# 11 . How do you install PyTorch?

# !pip install torch torchvision

# %%
# 12. What is the basic structure of a PyTorch neural network?

import torch
import torch.nn as nn
import torch.optim as optim

# Define the neural network model
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize the model, loss function, and optimizer
model = SimpleNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# 13. What is the significance of tensors in PyTorch?

# Tensors are the fundamental data structure in PyTorch, analogous to NumPy arrays but with additional capabilities like GPU acceleration.
# They are used to store and manipulate numerical data, making them essential for building and training deep learning models. Key benefits include:

# GPU Support: Tensors can be moved to and processed on GPUs for faster computations.
# Automatic Differentiation: Integrated with PyTorch's autograd module for gradient computation.
# High Flexibility: They support dynamic computational graphs, allowing for flexible model architectures.

# %%
# 14. What is the difference between torch.Tensor and torch.cuda.Tensor in PyTorch?

# torch.Tensor: Represents a tensor in CPU memory. Operations performed on this tensor are executed on the CPU.
# torch.cuda.Tensor: Represents a tensor allocated on GPU memory. Operations on this tensor are executed on the GPU.

# %%
# 15. What is the purpose of the torch.optim module in PyTorch?

# The torch.optim module provides optimization algorithms (optimizers) to update model parameters during training. It abstracts the parameter updates, allowing you to use methods like:

# SGD (Stochastic Gradient Descent):

optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# Adam:

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# These optimizers compute gradients (via backpropagation) and adjust parameters to minimize the loss function.

# %%
# 16. What are some common activation functions used in neural networks?
# ReLU (Rectified Linear Unit):
# ReLU(x)=max(0,x)
# Used widely due to its simplicity and efficiency.
# Sigmoid: Maps input to a range [0, 1], useful for binary classification.
# Tanh: Maps input to a range [-1, 1], often used in RNNs.
# Softmax: Converts logits to probabilities for multi-class classification.
# Leaky ReLU: Allows a small gradient for negative values, solving the "dying ReLU" problem.

# %%
# 17. What is the difference between torch.nn.Module and torch.nn.Sequential in PyTorch?

# torch.nn.Module:
# A base class for defining complex models. You can define layers and a custom forward method.

class MyModel(torch.nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()
        self.fc = torch.nn.Linear(10, 1)

    def forward(self, x):
        return self.fc(x)

# torch.nn.Sequential:
# A simpler way to stack layers in a sequential order without needing a custom forward method.

model = torch.nn.Sequential(
    torch.nn.Linear(10, 20),
    torch.nn.ReLU(),
    torch.nn.Linear(20, 1)
)

# %%
# 18. How can you monitor training progress in TensorFlow 2.0?
# Using TensorBoard:
# Log metrics, scalars, and model graphs during training.

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs')
model.fit(x_train, y_train, callbacks=[tensorboard_callback])

# Printing Metrics:
# Print loss and accuracy during each epoch using verbose=1 in model.fit.

# Custom Callbacks:
# Create a custom callback to monitor progress:


class MyCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"Epoch {epoch}: loss={logs['loss']}, accuracy={logs['accuracy']}")

# %%
# 19. How does the Keras API fit into TensorFlow 2.0?
# Keras is the high-level API for building and training models in TensorFlow 2.0. It provides:

# Simplified model creation (Sequential or functional API).
# Pre-built layers and utilities for data preprocessing.
# Support for custom training loops and callbacks.

# %%
# 20. What is an example of a deep learning project that can be implemented using TensorFlow 2.0?

import tensorflow as tf

# Load dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0  # Normalize data

# Define model
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile and train
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8659 - loss: 0.4736
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9553 - loss: 0.1475
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9682 - loss: 0.1083
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9737 - loss: 0.0863
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9783 - loss: 0.0692

# %%
# 21. What is the main advantage of using pre-trained models in TensorFlow and PyTorch?
# Transfer Learning: Pre-trained models reduce training time by leveraging knowledge from large datasets.
# High Accuracy: These models are already fine-tuned for feature extraction or specific tasks.
# Lower Resource Usage: Pre-trained models require fewer computational resources to achieve good performance.

# %% [markdown]
# # Practical

# %%
# 1. How do you install and verify that TensorFlow 2.0 was installed successfully?

# To install TensorFlow 2.0, you can use pip:
# !pip install tensorflow

# After installation, you can verify it by running the following Python code:
import tensorflow as tf
print(tf.__version__)
# Out:
# ...
# 2.17.1

# %%
# 2. How can you define a simple function in TensorFlow 2.0 to perform addition2?
import tensorflow as tf

@tf.function
def add(a, b):
    return a + b

# Example usage
result = add(3, 5)
print("The result of the addition is:", result)
# Out:
# The result of the addition is: tf.Tensor(8, shape=(), dtype=int32)

# %%
# 3. How can you create a simple neural network in TensorFlow 2.0 with one hidden layer?

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Create the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(784,)),  # Input layer and hidden layer
    Dense(10, activation='softmax')                    # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Example data (dummy)
x_train = tf.random.normal((100, 784))  # 100 samples of 784 features
y_train = tf.random.uniform((100,), maxval=10, dtype=tf.int32)

# Train the model
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.1239 - loss: 2.7520
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4628 - loss: 1.7490
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7041 - loss: 1.0920
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8028 - loss: 0.8097
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9725 - loss: 0.5141
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9630 - loss: 0.4027
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9691 - loss: 0.2995
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.2218
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9939 - loss: 0.1727
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9845 - loss: 0.1544

# %%
# 4. How can you visualize the training progress using TensorFlow and Matplotlib?

import matplotlib.pyplot as plt
import tensorflow as tf

# Example dataset and model
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Training with history tracking
history = model.fit(x_train, y_train, epochs=5, validation_data=(x_test, y_test))

# Visualize training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.8779 - loss: 0.4367 - val_accuracy: 0.9608 - val_loss: 0.1319
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.9662 - loss: 0.1156 - val_accuracy: 0.9704 - val_loss: 0.0954
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - accuracy: 0.9777 - loss: 0.0735 - val_accuracy: 0.9755 - val_loss: 0.0814
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9838 - loss: 0.0548 - val_accuracy: 0.9759 - val_loss: 0.0785
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9874 - loss: 0.0414 - val_accuracy: 0.9739 - val_loss: 0.0841

# %%
# 5. How do you install PyTorch and verify the PyTorch installation?

import torch
print(f"PyTorch version: {torch.__version__}")
print(f"Is CUDA available: {torch.cuda.is_available()}")
# Out:
# PyTorch version: 2.5.1+cu121
# Is CUDA available: False

# %%
# 6. How do you create a simple neural network in PyTorch?

import torch.nn as nn

# Define the network
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.hidden = nn.Linear(10, 128)  # Hidden layer
        self.output = nn.Linear(128, 1)  # Output layer

    def forward(self, x):
        x = torch.relu(self.hidden(x))
        x = torch.sigmoid(self.output(x))
        return x

model = SimpleNN()
print(model)
# Out:
# SimpleNN(
#   (hidden): Linear(in_features=10, out_features=128, bias=True)
#   (output): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
# 7. How do you define a loss function and optimizer in PyTorch?

import torch.optim as optim

# Example model
model = SimpleNN()

# Define loss function and optimizer
loss_function = nn.BCELoss()  # Binary Cross-Entropy Loss
optimizer = optim.Adam(model.parameters(), lr=0.001)

print(loss_function, optimizer)
# Out:
# BCELoss() Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
# 8. How do you implement a custom loss function in PyTorch?

import torch

# Define a custom loss function
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()

    def forward(self, predictions, targets):
        return torch.mean((predictions - targets) ** 2)  # Mean Squared Error

# Example usage
loss_function = CustomLoss()
predictions = torch.tensor([0.2, 0.5, 0.7])
targets = torch.tensor([0.0, 1.0, 0.0])
loss = loss_function(predictions, targets)
print(f"Custom Loss: {loss.item()}")
# Out:
# Custom Loss: 0.25999999046325684

# %%
# 9. How do you save and load a TensorFlow mode?


from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Create a simple model
model = Sequential([
    Dense(32, activation='relu', input_shape=(784,)),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Save the model
model.save('my_model')

# Load the saved model
loaded_model = tf.keras.models.load_model('my_model')

# Verify the model's architecture
loaded_model.summary()
